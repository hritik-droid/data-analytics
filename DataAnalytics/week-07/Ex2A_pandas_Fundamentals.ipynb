# %% [markdown]
# # Exercise 2.A Fundamentals of pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series

# %%
aa = [1, 2, 3, 4]

ab = (5, 6, 7, 8)

ac = {9, 10, 11, 12}

ad = {
    'first': 13,
    'second': 14,
    'third': 15,
    'fourth': 16
}

# %%
ser1 = pd.Series(aa)
ser2 = pd.Series(ab)
ser3 = pd.Series(list(ac))
ser4 = pd.Series(ad)

print(ser1)
print()
print(ser2)
print()
print(ser3)
print()
print(ser4)

# %%
try:
    ser5 = pd.Series(17, 18, 19, 20)
except TypeError as e:
    print(e)

# TypeError occurs because pd.Series expects one data object, not multiple separate integers.

# %% [markdown]
# ## DataFrames from Series

# %%
df1 = pd.DataFrame(ser1)

df1

# %%
df1.insert(1, "Column2", ser2)
df1.insert(2, "Column3", ser3)

df1

# %%
df1["Column4"] = ser4

df1

# ser4 uses dictionary keys as index labels instead of numeric indexes.
# Since the indexes do not match df1, pandas fills unmatched rows with NaN values.

# %%
df1.loc[4] = [5, 9, 12, 0]

df1

# %% [markdown]
# ## Reading Data into a DataFrame

# %%
df2 = pd.read_csv("sakila_example.csv")

df2

# %%
df2.head()

# %%
df2.tail(10)

# %%
df2.info()

# %% [markdown]
# From the info output we can determine:
# - The number of rows and columns
# - The data types of each column
# - Whether there are missing values
# - Approximate memory usage

# %%
df2.describe()

# %% [markdown]
# The describe output provides statistics such as:
# - Mean
# - Minimum and maximum values
# - Standard deviation
# - Quartiles
#
# Statistics for ID columns are usually less meaningful because IDs are identifiers rather than measurements.

# %%
df3 = pd.read_csv("northwind_example.csv")

df3

# %%
df3.describe()

# %% [markdown]
# The summarizations in this dataset may reflect sales or business data.
#
# Compared to sakila_example.csv, the results differ because the datasets contain different kinds of numerical information.

# %% [markdown]
# ## Coding a DataFrame

# %%
test_data = {
    'ID': [1, 2, 3, 4, 5, 6, 7, 8],
    'Name': ['Alicia', 'Bob', 'Charlie', 'Dominic', 'Eve', 'Frank', 'Grace', 'Heidi'],
    'Age': [25, np.nan, 22, 19, 31, 35, np.nan, 18],
    'City': ['NY', 'LA', 'Chicago', 'Houston', 'Phoenix', 'Boston', 'Austin', 'San Diego'],
    'Score': [85, 92, -1, 65, 78, np.nan, 55, 90]
}

# %%
df4 = pd.DataFrame(test_data)

df4

# %%
df4.to_csv("test_data.csv", index=False)

print("test_data.csv exported successfully.")
